# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
#import csv data

data = pd.read_csv(r'C:\Users\nicho\OneDrive\Έγγραφα\Φυσικό Αθήνας\Εργαστήριο Κατεύθυνσης\Άσκηση 1\data_GLE69.csv',delimiter=";")

data['date']=pd.to_datetime(data['date'])

data = data.replace("   null",0)

#data = data.replace("   null",np.nan)
#data = data.dropna()

#data['ESOI'] = (data['ESOI']*1e6).astype(int)
data['AATB'] = data['AATB'].astype(str).str.replace('.', '').astype(int)
#data['AATB'] = (data['AATB']*1e6).astype(int)
#data['LMKS'] = (data['LMKS']*1e6).astype(int)
#data['MOSC'] = (data['MOSC']*1e6).astype(int)
#data['NEWK'] = (data['NEWK']*1e6).astype(int)
#data['KIEL'] = (data['KIEL']*1e6).astype(int)
#data['KERG'] = (data['KERG']*1e6).astype(int)
#data['OULU'] = (data['OULU']*1e6).astype(int)
#data['APTY'] = (data['APTY']*1e6).astype(int)
#data['FSMT'] = (data['FSMT']*1e6).astype(int)
#data['INVK'] = (data['INVK']*1e6).astype(int)
#data['NAIN'] = (data['NAIN']*1e6).astype(int)
#data['THUL'] = (data['THUL']*1e6).astype(int)
#data['SOPO'] = (data['SOPO']*1e6).astype(int)
data['SOPO'] = data['SOPO'].astype(str).str.replace('.', '').astype(int)
#data['TERA'] = (data['TERA']*1e6).astype(int)
data['TERA'] = data['TERA'].astype(str).str.replace('.', '').astype(int)
# Out:
# C:\Users\nicho\AppData\Local\Temp\ipykernel_9928\37646035.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['AATB'] = data['AATB'].astype(str).str.replace('.', '').astype(int)
# C:\Users\nicho\AppData\Local\Temp\ipykernel_9928\37646035.py:27: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['SOPO'] = data['SOPO'].astype(str).str.replace('.', '').astype(int)
# C:\Users\nicho\AppData\Local\Temp\ipykernel_9928\37646035.py:29: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
data
# Out:
#                    date     ESOI     AATB     LMKS     MOSC    NEWK     KIEL  \
# 0   2005-01-20 00:00:00  150.050  1350650  377.058  193.775  84.485  141.816
# 1   2005-01-20 00:02:00  151.025  1360650  376.575  195.635  82.150  142.758
# 2   2005-01-20 00:04:00  148.305  1352750  383.950  188.365  84.005  141.550
# 3   2005-01-20 00:06:00  149.990  1363050  378.967  190.680  82.640  141.950
# 4   2005-01-20 00:08:00  145.495  1357350  375.600  190.825       0  144.817
# ..                  ...      ...      ...      ...      ...     ...      ...
# 715 2005-01-20 23:50:00  153.340  1361650  387.684  196.990  83.970  148.841
# 716 2005-01-20 23:52:00  151.905  1356150  387.508  196.760  83.605  150.784
# 717 2005-01-20 23:54:00  156.195  1355650  387.100  198.725  85.535  149.950
# 718 2005-01-20 23:56:00  153.630  1353650  391.016  203.600  85.635  150.650
# 719 2005-01-20 23:58:00  151.030  1361750  390.092  199.500  85.590  152.366
#
# ...

# %%
#plotting ESOI station
plt.figure(num=1,dpi=120)
plt.plot(data['date'].values,data['ESOI'].values)
plt.xticks(rotation=80)
plt.show()

#plotting KERG station
plt.figure(num=1,dpi=120)
plt.plot(data['date'].values,data['KERG'].values)
plt.xticks(rotation=80)
plt.show()

# %%
####filtering####
start_date="20-01-2005 00:00:00"
end_date="20-01-2005 23:59:00"


data_all = data

filtered_data=data_all.loc[(data_all['date']>start_date) & (data_all['date']<end_date)]

dates_filtered=filtered_data['date']
aatb_filtered=filtered_data['AATB'].values
esoi_filtered=filtered_data['ESOI'].values
kerg_filtered=filtered_data['KERG'].values
kiel_filtered=filtered_data['KIEL'].values
lmks_filtered=filtered_data['LMKS'].values
mosc_filtered=filtered_data['MOSC'].values
newk_filtered=filtered_data['NEWK'].values
oulu_filtered=filtered_data['OULU'].values
apty_filtered=filtered_data['APTY'].values
fsmt_filtered=filtered_data['FSMT'].values
invk_filtered=filtered_data['INVK'].values
nain_filtered=filtered_data['NAIN'].values
thul_filtered=filtered_data['THUL'].values
sopo_filtered=filtered_data['SOPO'].values
tera_filtered=filtered_data['TERA'].values


nmdb_sel=filtered_data.loc[(filtered_data['date']>start_date) & (filtered_data['date']<end_date) ]
aatb_selected=nmdb_sel["AATB"].values
esoi_selected=nmdb_sel["ESOI"].values
kerg_selected=nmdb_sel['KERG'].values
kiel_selected=nmdb_sel['KIEL'].values
lmks_selected=nmdb_sel['LMKS'].values
mosc_selected=nmdb_sel['MOSC'].values
newk_selected=nmdb_sel['NEWK'].values
oulu_selected=nmdb_sel['OULU'].values
apty_selected=nmdb_sel['APTY'].values
fsmt_selected=nmdb_sel['FSMT'].values
invk_selected=nmdb_sel['INVK'].values
nain_selected=nmdb_sel['NAIN'].values
thul_selected=nmdb_sel['THUL'].values
sopo_selected=nmdb_sel['SOPO'].values
tera_selected=nmdb_sel['TERA'].values

# %%
#plotting AATB station
plt.figure(num=1,dpi=120)
plt.plot(dates_filtered,aatb_selected)
plt.xticks(rotation=80)
plt.show()

#plotting ESOI station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,esoi_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting KERG station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,kerg_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting KIEL station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,kiel_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting LMKS station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,lmks_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting MOSC station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,mosc_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting NEWK station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,newk_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting OULU station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,oulu_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting APTY station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,aatb_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting FSMT station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,fsmt_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting INVK station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,invk_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting NAIN station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,nain_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting THUL station
#plt.figure(num=1,dpi=120)
#plt.plot(dates_filtered,thul_selected)
#plt.xticks(rotation=80)
#plt.show()

#plotting SOPO station
plt.figure(num=1,dpi=120)
plt.plot(dates_filtered,sopo_selected)
plt.xticks(rotation=80)
plt.show()

#plotting TERA station
plt.figure(num=1,dpi=120)
plt.plot(dates_filtered,tera_selected)
plt.xticks(rotation=80)
plt.show()

# %%
results_aatb=(aatb_filtered-np.mean(aatb_selected))/np.mean(aatb_selected)
results_esoi=(esoi_filtered-np.mean(esoi_selected))/np.mean(esoi_selected)
results_kerg=(kerg_filtered-np.mean(kerg_selected))/np.mean(kerg_selected)
results_kiel=(kiel_filtered-np.mean(kiel_selected))/np.mean(kiel_selected)
results_lmks=(lmks_filtered-np.mean(lmks_selected))/np.mean(lmks_selected)
results_mosc=(mosc_filtered-np.mean(mosc_selected))/np.mean(mosc_selected)
#results_newk=(newk_filtered-np.mean(newk_selected))/np.mean(newk_selected)
results_oulu=(oulu_filtered-np.mean(oulu_selected))/np.mean(oulu_selected)
results_apty=(apty_filtered-np.mean(apty_selected))/np.mean(apty_selected)
#results_fsmt=(fsmt_filtered-np.mean(fsmt_selected))/np.mean(fsmt_selected)
results_invk=(invk_filtered-np.mean(invk_selected))/np.mean(invk_selected)
results_nain=(nain_filtered-np.mean(nain_selected))/np.mean(nain_selected)
results_thul=(thul_filtered-np.mean(thul_selected))/np.mean(thul_selected)
results_sopo=(sopo_filtered-np.mean(sopo_selected))/np.mean(sopo_selected)
results_tera=(tera_filtered-np.mean(tera_selected))/np.mean(tera_selected)

# %%
#plotting AATB station filtered
plt.figure(num=3,dpi=120)
plt.title("GLE 69")
plt.plot(dates_filtered,results_aatb)
plt.xlabel("date")
plt.ylabel("platos")
plt.xticks(rotation=80)
plt.grid()
plt.show()

#plotting ESOI station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_esoi)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting KERG station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_kerg)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting KIEL station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_kiel)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting LMKS station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_lmks)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting MOSC station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_mosc)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting NEWK station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_newk)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting OULU station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_oulu)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting APTY station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_apty)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting FSMT station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_fsmt)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting INVK station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_invk)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting NAIN station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_nain)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting THUL station filtered
#plt.figure(num=3,dpi=120)
#plt.title("GLE 69")
#plt.plot(dates_filtered,results_thul)
#plt.xlabel("date")
#plt.ylabel("platos")
#plt.xticks(rotation=80)
#plt.grid()
#plt.show()

#plotting SOPO station filtered
plt.figure(num=3,dpi=120)
plt.title("GLE 69")
plt.plot(dates_filtered,results_sopo)
plt.xlabel("date")
plt.ylabel("platos")
plt.xticks(rotation=80)
plt.grid()
plt.show()

#plotting TERA station filtered
plt.figure(num=3,dpi=120)
plt.title("GLE 69")
plt.plot(dates_filtered,results_tera)
plt.xlabel("date")
plt.ylabel("platos")
plt.xticks(rotation=80)
plt.grid()
plt.show()

# %%
plt.plot(dates_filtered,results_tera, label = 'TERA')
plt.plot(dates_filtered,results_sopo, label = 'SOPO')
plt.plot(dates_filtered,results_esoi, label = 'ESOI')
plt.plot(dates_filtered,results_kerg, label = 'KERG')
plt.plot(dates_filtered,results_kiel, label = 'KIEL')
plt.plot(dates_filtered,results_apty, label = 'APTY')
plt.plot(dates_filtered,results_thul, label = 'THUL')
plt.plot(dates_filtered,results_invk, label = 'INVK')
plt.plot(dates_filtered,results_lmks, label = 'LMKS')
plt.plot(dates_filtered,results_oulu, label = 'OULU')
plt.plot(dates_filtered,results_mosc, label = 'MOSC')
plt.plot(dates_filtered,results_nain, label = 'NAIN')
plt.plot(dates_filtered,results_aatb, label = 'AATB')
plt.xlabel("date")
plt.ylabel("platos")
plt.xticks(rotation=80)
plt.legend()
plt.grid()
plt.show()
